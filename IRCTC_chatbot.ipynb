# %%
from google import genai

client = genai.Client(api_key="AIzaSyCGmQjLwv-_77eqr7lZuRnjHCEM5Mnc66U")

# %%
with open("train_dataset.txt","r") as f:
  kb = f.read()

# %%
prompt = f"""

youre a IRCTC Customer care executive your job is to provide answers to the
customer,
you should answer the m politely,
if there is any question out of your kb say you didnt know about this ,
only refer the kb and answer the question
{kb}
"""

# %%
#connection code

model = "gemini-2.5-flash"
chat = client.chats.create (
    model = model,
    config = {
        'system_instruction': prompt
    }
)

# %%
response = chat.send_message(" what is the arrival time of Vande Bharat Express? ")
print(response.text)
# Out:
# I apologize, but I do not have any information regarding the "Vande Bharat Express" in my current knowledge base.
